# %%
import openpyxl as pyxl
import pandas as pd
import numpy as np
import win32com.client as win32
from tkinter import *
from tkinter import messagebox
from TkinterDnD2 import DND_FILES, TkinterDnD
from PIL import Image, ImageTk

def drop_path(event):
    pathEntry.delete(0,"end")
    path = event.data

    try:
        if (path[0] == "{"):
            path = path.strip('{}')
        print(path)

    except Exception as e:
        print(e)
    pathEntry.insert("end", path) 

class MainApp():
    
    # accountInfo;
    # excelForm;
        
    def __init__(self, master):
        
        self.master = master
        self.master.title("LTS_Create Credential")
        self.master.resizable(width = True, height = True)
        self.mainFrame = Frame(master, relief ="solid", bd=2, bg="powderblue")
        self.mainFrame.pack(padx = 70, pady= 70, expand = True, fill = "both")


class LoadOption(MainApp):
    
    def __init__(self, mainApp):
        self.mainApp = mainApp
        self.loadFrame = LabelFrame(self.mainApp.mainFrame, relief = "solid", bd = 1, bg = "yellowgreen", text = "Load Option")
        self.loadFrame.pack(padx = 10, pady =10, side = "top", fill = "x")
        
        # path & browser button Frame
        self.pathFrame = Frame(self.loadFrame, relief = "solid", bd =1)
        self.pathFrame.pack(side = "left", fill="both", expand = True)
        
        self.accountLabel = Label (self.pathFrame, relief = "solid", bd = 1, text="Account Info File Full path")
        self.accountLabel.pack(anchor="w", padx=10, pady = 5, ipady=5)
        
        self.browseButton = Button(self.pathFrame, relief = "solid", bd =1, text ="Browse")
        self.browseButton.pack()
        
        self.accountPathEntry = Entry(self.pathFrame)
        self.accountPathEntry.pack(padx = 10, ipady = 3, fill = "x")
        self.accountPathEntry.drop_target_register(DND_FILES)
        self.accountPathEntry.dnd_bind("<<Drop>>", self.drop_path)
        
        self.excelLabel = Label (self.pathFrame, relief = "solid", bd = 1, text="Excel Form File Full path")
        self.excelLabel.pack(anchor="w", padx=10, pady = 5, ipady = 5)
        
        self.excelFormEntry = Entry(self.pathFrame)
        self.excelFormEntry.pack(padx = 10, ipady= 3, fill = "x")
        self.excelFormEntry.drop_target_register(DND_FILES)
        self.excelFormEntry.dnd_bind("<<Drop>>", self.drop_path)
        
        # File Type Option Frame
        self.optionFrame = Frame(self.loadFrame, relief = "solid", bd = 1)
        self.optionFrame.pack(side = "left", fill= "both")
        self.testButton = Button(self.optionFrame, text = "test", width = 20)
        self.testButton.pack()
        
        
        
        
        # Read & Clear Option Frame
        self.readFrame = Frame(self.loadFrame, relief = "solid", bd = 1)
        self.readFrame.pack(side = "left", fill = "both")
        self.testButton2 = Button(self.readFrame, text = "test", width = 10)
        self.testButton2.pack()
        
# tkinter event.key => tkinterDnD event.widget (event가 발생한 widget 호출), 함수 하나로 가능.

    def drop_path(self, event):
        event.widget.delete(0,"end")
        path = event.data
        print(event.widget);

        try:
            if (path[0] == "{"):
                path = path.strip('{}')
            print(path)

        except Exception as e:
            print(e)
        event.widget.insert("end", path) 

        
def main():
    root = TkinterDnD.Tk()
    scrWidth = root.winfo_screenwidth()
    scrHeight = root.winfo_screenheight()
    
    root.geometry("%sx%s" %(int(scrWidth/2), int(scrHeight*4/5)))
       
    
    app = MainApp(root)
    loading = LoadOption(app)
    root.mainloop()
    
if (__name__ == "__main__"):
    main()
# Out:
# .!frame.!labelframe.!frame.!entry
# E:/Fronteo/FKR/1. KR_PE/Case/(FRONTEO) Production Specification Questionnaire.docx

# %%
"""
===================================================================
Tkinter Table Test
"""

from tkinter import *
from tkintertable.Tables import TableCanvas
from tkintertable.TableModels import TableModel


"""
Free License : Darrell

"""


root = Tk()
root.title("Hello")
tframe = Frame(root)
tframe.pack(fill = X)
table = TableCanvas(tframe)

table.show()

root.mainloop()

# %%
"""
============================================

21-05-10 Tkinter DnD Test

===========================================
"""

def drop_path(event):
    pathEntry.delete(0,"end")
    path = event.data
       
    try:
        if (path[0] == "{"):
            path = path.strip('{}')
        print(path)
        
    except Exception as e:
        print(e)
    pathEntry.insert("end", path)   
    

from tkinter import *
from TkinterDnD2 import DND_FILES, TkinterDnD

root = TkinterDnD.Tk()
root.geometry("500x500+100+100")

pathEntry = Entry(root, width=50)
pathEntry.pack()
pathEntry.drop_target_register(DND_FILES)
pathEntry.dnd_bind("<<Drop>>", drop_path)


root.mainloop()
# Out:
# C:/Users/KYEONGRYUN_KIM/Desktop/Relativity_교육.txt
